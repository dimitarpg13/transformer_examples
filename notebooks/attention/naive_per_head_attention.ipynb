# %% [markdown]
# <a href="https://colab.research.google.com/github/dimitarpg13/transformer_examples/blob/main/notebooks/attention/naive_per_head_attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The following self-contained script constructs $h$ independent per-head projection matrices, applies them the naive way, and then stacks them into a fused $(d, d)$ matrix that reproduces the same result via one matmul plus a view.
